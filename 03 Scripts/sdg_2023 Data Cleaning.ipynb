# %% [markdown]
# # Table of Contents
# ### 01. Importing Libraries
# ### 02. Importing dataframes
# ### 03. Data consistency checks
# ### 04. Export Data

# %% [markdown]
# # 01 Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Importing dataframe

# %%
# Importing SDG 2023 dataframe
sdg_2023=pd.read_csv(('../02 Data/Original Data/sdg_2023.csv'),index_col=False)
sdg_2023.head()
# Out:
#   country_code  country region  overall_score  goal_1_score  goal_2_score  \
# 0          FIN  Finland   OECD      86.760595       99.5750     60.886750
# 1          SWE   Sweden   OECD      85.981397       98.8885     63.074125
# 2          DNK  Denmark   OECD      85.683637       99.2155     71.025250
# 3          DEU  Germany   OECD      83.358447       99.5105     72.366000
# 4          AUT  Austria   OECD      82.280189       99.4510     73.067500
#
#    goal_3_score  goal_4_score  goal_5_score  goal_6_score  ...  goal_8_score  \
# 0     95.386385     97.169333      92.11125       94.3276  ...     86.789000
# 1     96.904000     99.761667      91.44025       95.0576  ...     84.966429
# 2     95.398500     99.339667      86.99800       90.7316  ...     87.562429
# 3     93.039357     97.162667      81.92025       88.4434  ...     86.967286
# 4     92.468000     97.914333      84.57925       92.1636  ...     83.274143
#
# ...

# %% [markdown]
# # 03. Data consistency checks

# %%
sdg_2023.describe()
# Out:
#        overall_score  goal_1_score  goal_2_score  goal_3_score  goal_4_score  \
# count     166.000000    151.000000    166.000000    166.000000    166.000000
# mean       67.549197     75.234401     59.799100     69.694078     76.512968
# std        10.295499     31.169948     10.620853     20.354575     23.181919
# min        38.676086      0.000000     19.805800     12.952714      1.232250
# 25%        60.547488     55.779250     54.007188     51.860089     61.417938
# 50%        69.376528     93.300500     61.027500     75.437629     84.772875
# 75%        74.947511     98.950750     67.264335     85.524428     95.644063
# max        86.760595    100.000000     83.401125     97.115143     99.761667
#
#        goal_5_score  goal_6_score  goal_7_score  goal_8_score  goal_9_score  \
# count    166.000000    166.000000    166.000000    166.000000    166.000000
# mean      63.285420     66.710744     61.413598     71.952935     51.600648
# ...

# %%
#Check for mixed data type
for col in sdg_2023.columns.tolist():
  weird = (sdg_2023[[col]].applymap(type) != sdg_2023[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (sdg_2023[weird]) > 0:
    print (col)

# %% [markdown]
# No mixed data type

# %%
# Finding Missing data in sdg_2023 dataframe
sdg_2023.isnull().sum()
# Out:
# country_code      0
# country           0
# region            0
# overall_score     0
# goal_1_score     15
# goal_2_score      0
# goal_3_score      0
# goal_4_score      0
# goal_5_score      0
# goal_6_score      0
# goal_7_score      0
# goal_8_score      0
# goal_9_score      0
# goal_10_score    17
# goal_11_score     0
# goal_12_score     0
# goal_13_score     0
# goal_14_score    40
# goal_15_score     0
# goal_16_score     0
# goal_17_score     0
# dtype: int64

# %%
sdg_2023.dropna()
# Out:
#     country_code           country              region  overall_score  \
# 0            FIN           Finland                OECD      86.760595
# 1            SWE            Sweden                OECD      85.981397
# 2            DNK           Denmark                OECD      85.683637
# 3            DEU           Germany                OECD      83.358447
# 5            FRA            France                OECD      82.048343
# ..           ...               ...                 ...            ...
# 156          LBR           Liberia  Sub-Saharan Africa      49.883810
# 158          COD  Congo, Dem. Rep.  Sub-Saharan Africa      48.581701
# 159          SDN             Sudan  Sub-Saharan Africa      48.552594
# 161          SOM           Somalia  Sub-Saharan Africa      48.027231
# 162          YEM       Yemen, Rep.                MENA      46.846980
#
#      goal_1_score  goal_2_score  goal_3_score  goal_4_score  goal_5_score  \
# ...

# %%
sdg_2023=sdg_2023.dropna()

# %%
sdg_2023.isnull().sum()
# Out:
# country_code     0
# country          0
# year             0
# overall_score    0
# goal_1_score     0
# goal_2_score     0
# goal_3_score     0
# goal_4_score     0
# goal_5_score     0
# goal_6_score     0
# goal_7_score     0
# goal_8_score     0
# goal_9_score     0
# goal_10_score    0
# goal_11_score    0
# goal_12_score    0
# goal_13_score    0
# goal_14_score    0
# goal_15_score    0
# goal_16_score    0
# goal_17_score    0
# dtype: int64

# %%
sdg_2023=sdg_2023.drop(columns= ['region'])

# %%
# Add year column to the dataframe
sdg_2023.insert(2,'year',2023)

# %%
sdg_2023.head()
# Out:
#   country_code  country  year  overall_score  goal_1_score  goal_2_score  \
# 0          FIN  Finland  2023      86.760595       99.5750     60.886750
# 1          SWE   Sweden  2023      85.981397       98.8885     63.074125
# 2          DNK  Denmark  2023      85.683637       99.2155     71.025250
# 3          DEU  Germany  2023      83.358447       99.5105     72.366000
# 5          FRA   France  2023      82.048343       99.7285     72.390125
#
#    goal_3_score  goal_4_score  goal_5_score  goal_6_score  ...  goal_8_score  \
# 0     95.386385     97.169333      92.11125       94.3276  ...     86.789000
# 1     96.904000     99.761667      91.44025       95.0576  ...     84.966429
# 2     95.398500     99.339667      86.99800       90.7316  ...     87.562429
# 3     93.039357     97.162667      81.92025       88.4434  ...     86.967286
# 5     93.224571     99.630000      87.82325       89.2696  ...     85.306000
#
# ...

# %%
sdg_2023.shape
# Out:
# (107, 21)

# %%
# Finding Duplicates in sdg_2023 dataframe
df_dups=sdg_2023[sdg_2023.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [country_code, country, year, overall_score, goal_1_score, goal_2_score, goal_3_score, goal_4_score, goal_5_score, goal_6_score, goal_7_score, goal_8_score, goal_9_score, goal_10_score, goal_11_score, goal_12_score, goal_13_score, goal_14_score, goal_15_score, goal_16_score, goal_17_score]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# No Dublicate values

# %%
sdg_2023.describe()
# Out:
#        overall_score  goal_1_score  goal_2_score  goal_3_score  goal_4_score  \
# count     107.000000    107.000000    107.000000    107.000000    107.000000
# mean       68.641016     79.130724     60.063141     71.195926     79.405958
# std        10.182078     27.499112     10.575028     20.172474     20.848262
# min        46.846980      3.154500     21.898333     17.860923     24.333667
# 25%        61.814047     62.917000     54.108312     52.366750     62.629417
# 50%        70.434238     93.958500     61.065875     77.652143     88.012250
# 75%        76.359755     98.998500     67.527875     87.588626     97.166000
# max        86.760595    100.000000     83.401125     97.115143     99.761667
#
#        goal_5_score  goal_6_score  goal_7_score  goal_8_score  goal_9_score  \
# count    107.000000    107.000000    107.000000    107.000000    107.000000
# mean      63.038766     68.383014     63.129298     72.754105     55.338754
# ...

# %%
sdg_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 0 to 162
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country_code   107 non-null    category
#  1   country        107 non-null    category
#  2   year           107 non-null    category
#  3   overall_score  107 non-null    float64
#  4   goal_1_score   107 non-null    float64
#  5   goal_2_score   107 non-null    float64
#  6   goal_3_score   107 non-null    float64
#  7   goal_4_score   107 non-null    float64
#  8   goal_5_score   107 non-null    float64
#  9   goal_6_score   107 non-null    float64
#  10  goal_7_score   107 non-null    float64
#  11  goal_8_score   107 non-null    float64
#  12  goal_9_score   107 non-null    float64
#  13  goal_10_score  107 non-null    float64
#  14  goal_11_score  107 non-null    float64
#  15  goal_12_score  107 non-null    float64
#  16  goal_13_score  107 non-null    float64
# ...

# %%
#change data type
sdg_2023['country_code']=sdg_2023['country_code'].astype('category')
sdg_2023['country']=sdg_2023['country'].astype('category')

# %%
#change data type
sdg_2023['year']=sdg_2023['year'].astype('category')

# %%
sdg_2023.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 107 entries, 0 to 162
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   country_code   107 non-null    category
#  1   country        107 non-null    category
#  2   year           107 non-null    category
#  3   overall_score  107 non-null    float64
#  4   goal_1_score   107 non-null    float64
#  5   goal_2_score   107 non-null    float64
#  6   goal_3_score   107 non-null    float64
#  7   goal_4_score   107 non-null    float64
#  8   goal_5_score   107 non-null    float64
#  9   goal_6_score   107 non-null    float64
#  10  goal_7_score   107 non-null    float64
#  11  goal_8_score   107 non-null    float64
#  12  goal_9_score   107 non-null    float64
#  13  goal_10_score  107 non-null    float64
#  14  goal_11_score  107 non-null    float64
#  15  goal_12_score  107 non-null    float64
#  16  goal_13_score  107 non-null    float64
# ...

# %%
sdg_2023.describe()
# Out:
#        overall_score  goal_1_score  goal_2_score  goal_3_score  goal_4_score  \
# count     107.000000    107.000000    107.000000    107.000000    107.000000
# mean       68.641016     79.130724     60.063141     71.195926     79.405958
# std        10.182078     27.499112     10.575028     20.172474     20.848262
# min        46.846980      3.154500     21.898333     17.860923     24.333667
# 25%        61.814047     62.917000     54.108312     52.366750     62.629417
# 50%        70.434238     93.958500     61.065875     77.652143     88.012250
# 75%        76.359755     98.998500     67.527875     87.588626     97.166000
# max        86.760595    100.000000     83.401125     97.115143     99.761667
#
#        goal_5_score  goal_6_score  goal_7_score  goal_8_score  goal_9_score  \
# count    107.000000    107.000000    107.000000    107.000000    107.000000
# mean      63.038766     68.383014     63.129298     72.754105     55.338754
# ...

# %% [markdown]
# # 04. Export Data

# %%
# Export sdg_2023 Clean data to csv
sdg_2023.to_csv('../02 Data/Prepared Data/sdg_2023_clean.csv')
