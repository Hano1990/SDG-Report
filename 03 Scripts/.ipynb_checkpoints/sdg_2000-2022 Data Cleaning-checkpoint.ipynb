# %% [markdown]
# # Table of Contents
# ### 01. Importing Libraries
# ### 02. Importing dataframes
# ### 03. Data consistency checks
# ### 04. Export Data

# %% [markdown]
# # 01 Importing Libraries

# %%
# Import libraries
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Importing dataframe

# %%
# Importing SDG 2023 dataframe
sdg_2022=pd.read_csv(('../02 Data/Original Data/sdg_index_2000-2022.csv'),index_col=False)
sdg_2022.head()
# Out:
#   country_code      country  year  sdg_index_score  goal_1_score  \
# 0          AFG  Afghanistan  2000             36.0          28.8
# 1          AFG  Afghanistan  2001             36.3          28.8
# 2          AFG  Afghanistan  2002             36.3          28.8
# 3          AFG  Afghanistan  2003             36.7          28.8
# 4          AFG  Afghanistan  2004             37.1          28.8
#
#    goal_2_score  goal_3_score  goal_4_score  goal_5_score  goal_6_score  ...  \
# 0          27.3          19.2           1.6          20.8          32.4  ...
# 1          30.6          19.4           1.6          20.8          32.4  ...
# 2          30.7          19.7           1.6          20.8          32.7  ...
# 3          32.5          19.9           1.6          20.8          33.0  ...
# 4          32.1          21.1           1.6          20.8          33.3  ...
#
#    goal_8_score  goal_9_score  goal_10_score  goal_11_score  goal_12_score  \
# ...

# %% [markdown]
# # 03. Data consistency checks

# %%
sdg_2022.describe()
# Out:
#               year  sdg_index_score  goal_1_score  goal_2_score  goal_3_score  \
# count  4140.000000      4140.000000   4140.000000   4140.000000   4140.000000
# mean   2011.000000        63.685435     64.815628     57.735531     64.045652
# std       6.634051        10.776469     36.098836     11.121524     22.354993
# min    2000.000000        36.000000      0.000000      7.700000      5.900000
# 25%    2005.000000        55.075000     31.500000     52.400000     44.800000
# 50%    2011.000000        65.100000     81.000000     58.900000     70.200000
# 75%    2017.000000        72.000000     98.600000     65.300000     81.300000
# max    2022.000000        86.800000    100.000000     83.400000     97.300000
#
#        goal_4_score  goal_5_score  goal_6_score  goal_7_score  goal_8_score  \
# count   4140.000000   4140.000000   4140.000000   4140.000000   4140.000000
# mean      71.990048     55.803309     63.963188     57.340966     69.839493
# ...

# %%
#change data type
sdg_2022['country_code']=sdg_2022['country_code'].astype('category')
sdg_2022['country']=sdg_2022['country'].astype('category')
sdg_2022['year']=sdg_2022['year'].astype('category')

# %%
#Check for mixed data type
for col in sdg_2022.columns.tolist():
  weird = (sdg_2022[[col]].applymap(type) != sdg_2022[[col]].iloc[0].apply(type)).any(axis = 1)
  if len (sdg_2022[weird]) > 0:
    print (col)

# %% [markdown]
# No mixed data type

# %%
# Finding Missing data in sdg_2022 dataframe
sdg_2022.isnull().sum()
# Out:
# country_code       0
# country            0
# year               0
# sdg_index_score    0
# goal_1_score       0
# goal_2_score       0
# goal_3_score       0
# goal_4_score       0
# goal_5_score       0
# goal_6_score       0
# goal_7_score       0
# goal_8_score       0
# goal_9_score       0
# goal_10_score      0
# goal_11_score      0
# goal_12_score      0
# goal_13_score      0
# goal_14_score      0
# goal_15_score      0
# goal_16_score      0
# goal_17_score      0
# dtype: int64

# %% [markdown]
# No missing values found

# %%
# Finding Duplicates in sdg_2023 dataframe
df_dups=sdg_2022[sdg_2022.duplicated()]

# %%
df_dups
# Out:
# Empty DataFrame
# Columns: [country_code, country, year, sdg_index_score, goal_1_score, goal_2_score, goal_3_score, goal_4_score, goal_5_score, goal_6_score, goal_7_score, goal_8_score, goal_9_score, goal_10_score, goal_11_score, goal_12_score, goal_13_score, goal_14_score, goal_15_score, goal_16_score, goal_17_score]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# No Dublicate values

# %%
# Ranaming sdg_index_score column
sdg_2022.rename(columns={'sdg_index_score':'overall_score'}, inplace=True)
sdg_2022.head()
# Out:
#   country_code      country  year  overall_score  goal_1_score  goal_2_score  \
# 0          AFG  Afghanistan  2000           36.0          28.8          27.3
# 1          AFG  Afghanistan  2001           36.3          28.8          30.6
# 2          AFG  Afghanistan  2002           36.3          28.8          30.7
# 3          AFG  Afghanistan  2003           36.7          28.8          32.5
# 4          AFG  Afghanistan  2004           37.1          28.8          32.1
#
#    goal_3_score  goal_4_score  goal_5_score  goal_6_score  ...  goal_8_score  \
# 0          19.2           1.6          20.8          32.4  ...          38.5
# 1          19.4           1.6          20.8          32.4  ...          38.5
# 2          19.7           1.6          20.8          32.7  ...          38.4
# 3          19.9           1.6          20.8          33.0  ...          38.4
# 4          21.1           1.6          20.8          33.3  ...          38.5
#
# ...

# %%
sdg_2022.describe()
# Out:
#        overall_score  goal_1_score  goal_2_score  goal_3_score  goal_4_score  \
# count    4140.000000   4140.000000   4140.000000   4140.000000   4140.000000
# mean       63.685435     64.815628     57.735531     64.045652     71.990048
# std        10.776469     36.098836     11.121524     22.354993     26.561757
# min        36.000000      0.000000      7.700000      5.900000      0.000000
# 25%        55.075000     31.500000     52.400000     44.800000     57.375000
# 50%        65.100000     81.000000     58.900000     70.200000     80.600000
# 75%        72.000000     98.600000     65.300000     81.300000     94.400000
# max        86.800000    100.000000     83.400000     97.300000    100.000000
#
#        goal_5_score  goal_6_score  goal_7_score  goal_8_score  goal_9_score  \
# count   4140.000000   4140.000000   4140.000000   4140.000000   4140.000000
# mean      55.803309     63.963188     57.340966     69.839493     37.114444
# ...

# %% [markdown]
# # 04. Export Data

# %%
# Export sdg_2022 Clean data to pkl
sdg_2022.to_csv('../02 Data/Prepared Data/sdg_2000-2022_clean.csv')
