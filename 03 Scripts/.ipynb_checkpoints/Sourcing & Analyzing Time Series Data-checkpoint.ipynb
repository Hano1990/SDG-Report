# %% [markdown]
# # Table of Contents
# ### 01. Visualization and Data Library Importation
# ### 02. Importing dataframe
# ### 03. Subsetting, wrangling, and cleaning time-series data
# ### 04. Time series analysis: decomposition
# ### 05. Testing for stationarity
# ### 06. Stationarizing the Federal Reserve Economic Data

# %% [markdown]
# #### 01. Visualization and Data Library Importation

# %%
# Importing Libraries
import quandl
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import statsmodels.api as sm # Using .api imports the public access version of statsmodels, which is a library that handles 
# statistical models.
import os
import warnings # This is a library that handles warnings.

warnings.filterwarnings("ignore") # Disable deprecation warnings that could indicate, for instance, a suspended library or 
# feature. These are more relevant to developers and very seldom to analysts.

plt.style.use('fivethirtyeight') # This is a styling option for how your plots will appear. More examples here:
# https://matplotlib.org/3.2.1/tutorials/introductory/customizing.html
# https://matplotlib.org/3.1.0/gallery/style_sheets/fivethirtyeight.html

# %% [markdown]
# #### 02. Importing dataframe

# %%
# Importing sdg_merged dataframe
sdg_merged=pd.read_csv(('../02 Data/Prepared Data/sdg merged wrengled.csv'),index_col=0)
sdg_merged.head()
# Out:
#   country_code      country  year  overall_score  No Poverty  Zero Hunger  \
# 0          AFG  Afghanistan  2000           36.0        28.8         27.3
# 1          AFG  Afghanistan  2001           36.3        28.8         30.6
# 2          AFG  Afghanistan  2002           36.3        28.8         30.7
# 3          AFG  Afghanistan  2003           36.7        28.8         32.5
# 4          AFG  Afghanistan  2004           37.1        28.8         32.1
#
#    Good Health and Wellbeing  Quality Education  Gender Equality  \
# 0                       19.2                1.6             20.8
# 1                       19.4                1.6             20.8
# 2                       19.7                1.6             20.8
# 3                       19.9                1.6             20.8
# 4                       21.1                1.6             20.8
#
#    Clean Water and Sanitation  ...  Industry, Innovation and Infrastructure  \
# ...

# %%
sdg_merged.shape
# Out:
# (4247, 22)

# %% [markdown]
# #### 03. Subsetting, wrangling, and cleaning time-series data

# %%
type(sdg_merged)
# Out:
# pandas.core.frame.DataFrame

# %%
# Create subset of avg war, ts_mil, as_mil, contract_length, and games for each year

sdg_average = sdg_merged.groupby('year', as_index=False)['overall_score'].mean()

# %%
data_sub = sdg_average[['year','overall_score']]

# %%
# Set the "Date" column as the index

from datetime import date

data_sub['datetime'] = pd.to_datetime(data_sub['year'], format='%Y') # Create a datetime column from "Date.""
data_sub = data_sub.set_index('datetime') # Set the datetime as the index of the dataframe.
data_sub.drop(['year'], axis=1, inplace=True) # Drop the "Date" column.
data_sub.head()
# Out:
#             overall_score
# datetime
# 2000-01-01      60.314444
# 2001-01-01      60.511111
# 2002-01-01      60.766667
# 2003-01-01      60.946111
# 2004-01-01      61.230000

# %%
# Plot the new data set

plt.figure(figsize=(15,5), dpi=100)
plt.plot(data_sub)

# %% [markdown]
# #### 04. Time series analysis: decomposition

# %%
# Decompose the time series using an additive model

decomposition = sm.tsa.seasonal_decompose(data_sub, model='additive')

# %%
from pylab import rcParams # This will define a fixed size for all special charts.

rcParams['figure.figsize'] = 18, 7

# %%
# Plot the separate components

decomposition.plot()
plt.show()

# %% [markdown]
# ##### Observations
# - trend: positive trend
# - seasonality: no apparent seasonality
# - noise: no apparent noise
#
# I would expect this data to be non-stationary because there is a clear upwards trend.

# %% [markdown]
# #### 05. Testing for stationarity

# %% [markdown]
# - Conduct a Dickey-Fuller test to check for stationarity

# %%
# The adfuller() function will import from the model from statsmodels for the test; however, running it will only return 
# an array of numbers. This is why you need to also define a function that prints the correct output from that array.

from statsmodels.tsa.stattools import adfuller # Import the adfuller() function

def dickey_fuller(timeseries): # Define the function
    # Perform the Dickey-Fuller test:
    print ('Dickey-Fuller Stationarity test:')
    test = adfuller(timeseries, autolag='AIC')
    result = pd.Series(test[0:4], index=['Test Statistic','p-value','Number of Lags Used','Number of Observations Used'])
    for key,value in test[4].items():
       result['Critical Value (%s)'%key] = value
    print (result)

# Apply the test using the function on the time series
dickey_fuller(data_sub['overall_score'])
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                 -0.110027
# p-value                         0.948431
# Number of Lags Used             9.000000
# Number of Observations Used    14.000000
# Critical Value (1%)            -4.012034
# Critical Value (5%)            -3.104184
# Critical Value (10%)           -2.690987
# dtype: float64

# %% [markdown]
# - The test Statistic value is -0.11 which is larger than critical value of 5% (-3.10), which mean we can’t reject null hypothesis. this result indicat that there is a unit root in the data and it is non-stationary.

# %% [markdown]
# #### 06. Stationarizing the Data

# %%
#perform differencing
data_diff = data_sub - data_sub.shift(1) # The df.shift(1) function turns the observation to t-1, making the whole thing t - (t -1)

# %%
data_diff.dropna(inplace = True) # Here, you remove the missing values that came about as a result of the differencing. 
# You need to remove these or you won't be able to run the Dickey-Fuller test.

# %%
data_diff.head()
# Out:
#             overall_score
# datetime
# 2001-01-01       0.196667
# 2002-01-01       0.255556
# 2003-01-01       0.179444
# 2004-01-01       0.283889
# 2005-01-01       0.307222

# %%
data_diff.columns
# Out:
# Index(['overall_score'], dtype='object')

# %%
# Check out what the differencing did to the time-series curve

plt.figure(figsize=(15,5), dpi=100)
plt.plot(data_diff)

# %%
#Repeat the dickey-fuller test
dickey_fuller(data_diff)
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                 -1.479225
# p-value                         0.543762
# Number of Lags Used             9.000000
# Number of Observations Used    13.000000
# Critical Value (1%)            -4.068854
# Critical Value (5%)            -3.127149
# Critical Value (10%)           -2.701730
# dtype: float64

# %%
# perform differencing second time
data_diff2 = data_diff - data_diff.shift(1)

# %%
data_diff2.dropna(inplace = True)

# %%
#Repeat the dickey-fuller test
dickey_fuller(data_diff2)
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                 -1.323295
# p-value                         0.618449
# Number of Lags Used             7.000000
# Number of Observations Used    14.000000
# Critical Value (1%)            -4.012034
# Critical Value (5%)            -3.104184
# Critical Value (10%)           -2.690987
# dtype: float64

# %%
#perform differencing third time
data_diff3 = data_diff2 - data_diff2.shift(1)

# %%
data_diff3.dropna(inplace = True)

# %%
#Repeat the dickey-fuller test
dickey_fuller(data_diff3)
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                 -1.429245
# p-value                         0.568178
# Number of Lags Used             7.000000
# Number of Observations Used    13.000000
# Critical Value (1%)            -4.068854
# Critical Value (5%)            -3.127149
# Critical Value (10%)           -2.701730
# dtype: float64

# %%
#perform differencing fourth time
data_diff4 = data_diff3 - data_diff3.shift(1)

# %%
data_diff4.dropna(inplace = True)

# %%
dickey_fuller(data_diff4)
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                 -1.167858
# p-value                         0.687267
# Number of Lags Used             7.000000
# Number of Observations Used    12.000000
# Critical Value (1%)            -4.137829
# Critical Value (5%)            -3.154972
# Critical Value (10%)           -2.714477
# dtype: float64

# %%
#perform differencing fifth time
data_diff5 = data_diff4 - data_diff4.shift(1)
data_diff5.dropna(inplace = True)
dickey_fuller(data_diff5)
# Out:
# Dickey-Fuller Stationarity test:
# Test Statistic                 -5.346858
# p-value                         0.000004
# Number of Lags Used             5.000000
# Number of Observations Used    13.000000
# Critical Value (1%)            -4.068854
# Critical Value (5%)            -3.127149
# Critical Value (10%)           -2.701730
# dtype: float64

# %% [markdown]
# - The test Statistic value is -5.35 after repeatedly performing differencing five times which is smaller than critical value of 5% and 10%, which mean we can reject null hypothesis now. this result indicat that there is no unit root in the data and it is stationary.

# %%
# Check out what the differencing did to the time-series curve

plt.figure(figsize=(15,5), dpi=100)
plt.plot(data_diff5)

# %%
#Create a plot of autocorrelations again

plot_acf(data_diff5)
plt.show()
